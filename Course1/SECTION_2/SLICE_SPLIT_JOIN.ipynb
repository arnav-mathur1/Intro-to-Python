# %%
robot = "technologically"

consoles = "ps4 is cooler than xbox!"

code = "p1y2t3h4o5n6i7c8"

words = "I saw a cat jump over the moon and into the clouds"

new_words = "I saw a cow jump over the gates and into the forest"

pay = "I recieved a total of $5000"

# %%
len(robot)
# Out:
# 15

# %%
robot
# Out:
# 'technologically'

# %%
robot[0:6] # the splice is essentially [0:5] only
# Out:
# 'techno'

# %%
robot[6:]
# Out:
# 'logically'

# %%
robot[10:14]
# Out:
# 'call'

# %%
consoles.endswith("-")
# Out:
# False

# %%
len(consoles)
# Out:
# 24

# %%
consoles[23]
# Out:
# '!'

# %%
consoles.find("!")
# Out:
# 23

# %%
consoles[7:13]
# Out:
# 'cooler'

# %%
consoles[-17:-11]
# Out:
# 'cooler'

# %%
consoles[23]
# Out:
# '!'

# %%
code
# Out:
# 'p1y2t3h4o5n6i7c8'

# %%
code.replace("1", "").replace("2", "") # ... This method is inefficient
# Out:
# 'pyt3h4o5n6i7c8'

# %%
code[0:1] + code[2:3] + code [4:5] # ... This method is also inefficient
# Out:
# 'pyt'

# %%
code[0::2].upper()
# Out:
# 'PYTHONIC'

# %%
code[1::2][::-2]
# Out:
# '8642'

# %%
var = words.split()
var
# Out:
# ['I',
#  'saw',
#  'a',
#  'cat',
#  'jump',
#  'over',
#  'the',
#  'moon',
#  'and',
#  'into',
#  'the',
#  'clouds']

# %%
len(var)
var[3:12:2]
# Out:
# ['cat', 'over', 'moon', 'into', 'clouds']

# %%
new_words
# Out:
# 'I saw a cow jump over the gates and into the forest'

# %%
s1 = slice(3, 12, 2)
new_words.split()[s1]
# Out:
# ['cow', 'over', 'gates', 'into', 'forest']

# %%
var[s1]
# Out:
# ['cat', 'over', 'moon', 'into', 'clouds']

# %%
"dog" not in var and "cow" not in new_words.split()
# Out:
# False

# %%
" ".join(var)
# Out:
# 'I saw a cat jump over the moon and into the clouds'

# %%
words
# Out:
# 'I saw a cat jump over the moon and into the clouds'

# %%
pay.split("$")[1]
# Out:
# '5000'
