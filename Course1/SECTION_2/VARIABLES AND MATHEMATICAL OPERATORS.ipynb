# %%
var = 4
print(9/var)
print(9//var) #floor division
print(9%var) #modulus
print(9 - (2*var))
# Out:
# 2.25
# 2
# 1
# 1

# %%
x, y, z = 25, 80, 9.12345
type(z)

x_float = float(x)
type(x_float)

z_int = int(z)
z_int
type(z_int)
# Out:
# int
