# %%
d1 = {}
type(d1)
d1["A"] = 10
d1["B"] = 20
d1["C"] = 50
d1
# Out:
# {'A': 10, 'B': 20, 'C': 50}

# %%
toys = {"robot": "$25.99", "car": "$45.95"}
d1.update(toys)
d1["A"] = 120
d1["D"] = 300
d1
# Out:
# {'A': 120, 'B': 20, 'C': 50, 'robot': '$25.99', 'car': '$45.95', 'D': 300}

# %%
# mylist = [10, 20]
# mylist[0] = 120
# mylist.append(300)
# mylist
# Out:
# [120, 20, 300]

# %%
# toys.clear()
# toys
# Out:
# {}

# %%
d1.pop("A")
d1
# Out:
# {'B': 20, 'C': 50, 'robot': '$25.99', 'car': '$45.95', 'D': 300}

# %%
# CONVERT INTO LIST OR TUPLE FOR INDEXING
list(d1.values())[2: 4]
# Out:
# ['$25.99', '$45.95']

# %%
tuple(d1.keys())[2: 4]
# Out:
# ('robot', 'car')

# %%
dict(list(d1.items()))
# Out:
# {'B': 20, 'C': 50, 'robot': '$25.99', 'car': '$45.95', 'D': 300}

# %%
menu = [("chips", 2.4), ("soup", 1.4)]
dict(menu)
# Out:
# {'chips': 2.4, 'soup': 1.4}

# %%
maze = {"k1": d1,
       "k2": [10, 20, 30],
       "k3": ("tuple!", [1, 2, {"k4": ["a", "b", "catch me!"]}])}
maze
# Out:
# {'k1': {'B': 20, 'C': 50, 'robot': '$25.99', 'car': '$45.95', 'D': 300},
#  'k2': [10, 20, 30],
#  'k3': ('tuple!', [1, 2, {'k4': ['a', 'b', 'catch me!']}])}

# %%
maze["k3"][1][2]["k4"][2]
# Out:
# 'catch me!'
