# %%
import numpy as np

# %%
np.random.seed(10)
data = np.random.randint(1, 100, size = (5, 4))
data
# Out:
# array([[10, 16, 65, 29],
#        [90, 94, 30,  9],
#        [74,  1, 41, 37],
#        [17, 12, 55, 89],
#        [63, 34, 73, 79]])

# %%
data[[1, 3], [2, 1]]
data[:3, [1, 3]][0][0]
data[0][2]
data[0, 2]
data[4, 1]
# Out:
# 34

# %%
data[[1, 3]]
# Out:
# array([[90, 94, 30,  9],
#        [17, 12, 55, 89]])

# %%
# data[0]
# data[2]
# data[4:]
# data[:, 0:1] # First Column
# data[:, 2:]
# data[2:4, 1:3]
# data[4:, 1:2][0][0]
# Out:
# 34
