# %%
desk = "C:/Users/Arnav/Desktop/"
f = open(desk + "first.txt", "w")
f.write("This is my first file!")
f.write("\nHello world!")
f.close()

# %%
f1 = open(desk + "first.txt", "a")
f1.write("\nGood Night!")
f1.close()

# %%
with open(desk + "first.txt", "a") as g: 
    g.write("\nCool!") # when using 'with open', the .close() method is not required

# %%
f2 = open(desk + "first.txt", "r")
print(f2.read())
f2.close()
# Out:
# This is my first file!
# Hello world!
# Good Night!
# Cool!

# %%
gear = ["Blade Wold", "Raiden", "Sam"]
path = "C:/Users/Arnav/Desktop/FILE_{}/second.txt"
for i in range(len(gear)):
    with open(path.format(i), "w") as f3:
        f3.write(gear[i])
#         f3.write("\n" + gear[1])
        
        f3.write("\n{} is cooler than {}".format(gear[0], gear[1]))

# %%
simpsons = [["Bart in detention", "Lisa at MIT"], ["Doughnuts...Mmm", "Homer: 'Nom, nom, nom!'"]]
transformers = [["HotRod opens matrix", "Optimus returns!"], ["Unicron explodes", "Megatron jumps"]]

def File(text):
    path = "C:/Users/Arnav/Desktop/"
   
    for i in range(len(text)):
        with open(path + "cartoon_{}.txt".format(i), "w") as f:
            f.write(text[i][0])
            f.write("\n" + text[i][1])
File(transformers)

# %%
dc = open("skynet.txt", "w")
dc.write("""Terminator is \n
hunting John conner \n
and Sarah is protecting him""")
dc.close()

# %%
d = open("skynet.txt", "r+")
d.write("\n hasta la vista baby!")
end = d.readlines()
d.close()

# %%
film = "".join(end)

# %%
"Terminator" in film.replace("\n", " ").split()
# Out:
# True
