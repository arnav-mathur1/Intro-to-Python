# %%
import pandas as pd
path = "/Users/arnavmathur/Desktop/DATA_1/"

# %%
states = pd.read_html("https://simple.wikipedia.org/wiki/List_of_U.S._states")

# %%
states
type(states)
len(states)
df_html = states[0]

# %%
df_html.to_csv(path + "HTML_DATA.csv", index = True, header = False)

# %%
usa = pd.read_csv(path + "HTML_DATA.csv", index_col = 0)

# %%
usa.loc[1]
# Out:
# Alabama              Alaska
# AL                       AK
# Montgomery           Juneau
# Birmingham        Anchorage
# Dec 14, 1819    Jan 3, 1959
# 4903185              731545
# 52420                665384
# 135767              1723337
# 50645                570641
# 131171              1477953
# 1775                  94743
# 4597                 245384
# 7                         1
# Name: 1, dtype: object

# %%
df = pd.DataFrame({"a": [10, 20, 30], "b": [1, 2, 3]})
df
# Out:
#     a  b
# 0  10  1
# 1  20  2
# 2  30  3

# %%
df.to_csv(path + "CSV_DATA.csv", sep = ",", index = True)

# %%
df2 = pd.read_csv(path + "CSV_DATA.csv", index_col = 0)

# %%
df2
# Out:
#     a  b
# 0  10  1
# 1  20  2
# 2  30  3

# %%
df.to_excel(path + "EXCEL_DATA.xlsx", sheet_name = "Sheet1")

# %%
pd.read_excel(path + "EXCEL_DATA.xlsx")
# Out:
#    Unnamed: 0   a  b
# 0           0  10  1
# 1           1  20  2
# 2           2  30  3
