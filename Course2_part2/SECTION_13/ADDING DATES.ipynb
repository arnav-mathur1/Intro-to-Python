# %%
import pandas as pd, numpy as np

# %%
year = pd.period_range(start = "1/1/2017", end = "12/31/2017", freq = "M", name = "Special Year")
len(year)
# Out:
# 12

# %%
pd.period_range("2017", freq = "A-NOV", periods = 10)
# Out:
# PeriodIndex(['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024',
#              '2025', '2026'],
#             dtype='period[A-NOV]', freq='A-NOV')

# %%
np.random.seed(121)
stock1 = pd.Series(np.random.randint(1, 100, 12), year)
stock2 = pd.Series(np.random.randint(1, 100, 12), year)
df = pd.DataFrame({"APPL": stock1, "MSFT": stock2})
df
# Out:
#               APPL  MSFT
# Special Year
# 2017-01         67    55
# 2017-02         86     4
# 2017-03          9    95
# 2017-04         96    53
# 2017-05         66    58
# 2017-06         53    76
# 2017-07         84    89
# 2017-08         97    40
# 2017-09         47    22
# 2017-10         35    42
# 2017-11         53    56
# 2017-12         61    84

# %%
df["2017-01": "2017-04"]["APPL"]
# Out:
# Special Year
# 2017-01    67
# 2017-02    86
# 2017-03     9
# 2017-04    96
# Freq: M, Name: APPL, dtype: int64

# %%
np.random.seed(123)
hr = pd.date_range("5/1/2017", periods = 5, freq = "D")
ts = pd.Series(np.random.randn(len(hr)), index = hr)
ts
# Out:
# 2017-05-01   -1.085631
# 2017-05-02    0.997345
# 2017-05-03    0.282978
# 2017-05-04   -1.506295
# 2017-05-05   -0.578600
# Freq: D, dtype: float64
