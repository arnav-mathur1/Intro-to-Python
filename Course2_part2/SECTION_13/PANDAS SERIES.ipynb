# %%
import pandas as pd

# %%
len(dir(pd))
# Out:
# 141

# %%
rad = pd.Series([10, 20, 30, 40], index = ["a", "b", "c", "d"], name = "First_Series")
rad.name
# Out:
# 'First_Series'

# %%
ds = pd.Series(list(range(10, 110, 10)), index = list("ABCDEFGHIJ"))
ds
# Out:
# A     10
# B     20
# C     30
# D     40
# E     50
# F     60
# G     70
# H     80
# I     90
# J    100
# dtype: int64

# %%
ds.head(2)
ds.tail(3)
# Out:
# H     80
# I     90
# J    100
# dtype: int64

# %%
ds
# Out:
# A     10
# B     20
# C     30
# D     40
# E     50
# F     60
# G     70
# H     80
# I     90
# J    100
# dtype: int64

# %%
ds[3:7]
ds[::-1]
ds[3:7][::-1]
# Out:
# G    70
# F    60
# E    50
# D    40
# dtype: int64

# %%
ds[0] = 123
ds
# Out:
# A    123
# B     20
# C     30
# D     40
# E     50
# F     60
# G     70
# H     80
# I     90
# J    100
# dtype: int64

# %%
# ds//3
list(ds.index)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
ds.sum()
ds.mean()
ds.var()
ds.std()
ds.max()
ds.min()
ds.values
ds.count()
# Out:
# 10

# %%
ds.describe()
# Out:
# count     10.00000
# mean      66.30000
# std       32.61237
# min       20.00000
# 25%       42.50000
# 50%       65.00000
# 75%       87.50000
# max      123.00000
# dtype: float64

# %%
ds2 = pd.Series([10, 20, 30, 10, 10, 10, 4, 2, 2, 2])
ds2
# Out:
# 0    10
# 1    20
# 2    30
# 3    10
# 4    10
# 5    10
# 6     4
# 7     2
# 8     2
# 9     2
# dtype: int64

# %%
ds2.unique()
# Out:
# array([10, 20, 30,  4,  2])

# %%
set(ds2)
# Out:
# {2, 4, 10, 20, 30}

# %%
ds2.nunique()
# Out:
# 5

# %%
len(set(ds2))
# Out:
# 5
