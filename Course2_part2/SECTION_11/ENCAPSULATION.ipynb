# %%
class FinalValue:
    
    def __init__(self, num1, num2):
        self.__num1 = num1
        self.__num2 = num2
        self._val = [10, 20, 30]
        
    def Combine(self):
        c1 = self.__Calc1()
        c2 = self.__Calc2()
        
        return c1 + c2
    
    def __Calc1(self):
        return self.__num1 * 2
    
    def __Calc2(self):
        return self.__num2 * 2
    
c = FinalValue(10, 20)
c.Combine()
c._val
# Out:
# [10, 20, 30]
