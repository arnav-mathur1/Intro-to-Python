# %%
class Vehicle():
    
    """THIS IS A VEHICLE CLASS"""
    
    a = 10
    b = 34
    c = 12000
    
    def __init__(self, vehicle, fuel, color = "red"):
        self.vehicle = vehicle
        self.fuel = fuel
        self.color = color
        
    def Drive(self):
        print("My {} is colored {} and uses {} fuel.".format(self.vehicle, self.color. self.fuel))
