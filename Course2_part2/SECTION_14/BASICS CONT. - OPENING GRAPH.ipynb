# %%
from PIL import Image
myImage = Image.open("/Users/arnavmathur/Desktop/MATPLOTLIB/My_first_graph.png")
myImage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1067x406 at 0x107624810>
