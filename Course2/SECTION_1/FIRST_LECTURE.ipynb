# %%
print("CLICK ARROW TO RUN CODE IN CELL!")

# %%
print("HOLD SHIFT + ENTER TO RUN CODE IN CELL!")
# Out:
# CLICK ARROW TO RUN CODE IN CELL!
# HOLD SHIFT + ENTER TO RUN CODE IN CELL!

# %%
print("Hold ctrl or command + left click mouse for multi cursor!")
print("Hold ctrl or command + left click mouse for multi cursor!")
print("Hold ctrl or command + left click mouse for multi cursor!")
print("Hold ctrl or command + left click mouse for multi cursor!")
print("Hold ctrl or command + left click mouse for multi cursor!")
print("Hello Jupyter notebook!")
print("Add me ")

# THIS IS A COMMENT
# CTRL + FORWARD SLASH creates a comment for all code
# Out:
# Hold ctrl or command + left click mouse for multi cursor!
# Hold ctrl or command + left click mouse for multi cursor!
# Hold ctrl or command + left click mouse for multi cursor!
# Hold ctrl or command + left click mouse for multi cursor!
# Hold ctrl or command + left click mouse for multi cursor!
# Hello Jupyter notebook!
