# %%
# TASK 1

# %%
num = [10, 20, 30, 40] 
a = max(num); b = min(num); c = sum(num)
add_up = "{} + {} + {}"
eval(add_up.format(a, b, c))
# Out:
# 150

# %%
# TASK 2

# %%
pay_slip1 = ["A", "data scientist", "B", "Omar", "C", 55000] 
pay_slip1[1::2]
employee.format(*pay_slip1[1::2], 7000).replace("###", "").replace("!!!", "")
# Out:
# 'The annual salary, for data scientist Omar is $55000 + $7000 BONUS!'

# %%
pay_slip2 = [ "A", "python developer", "B", "Gemma",  "C", 34000]
pay_slip2[1::2]
employee.format(*pay_slip2[1::2], 7000).replace("###", "").replace("!!!", "")
# Out:
# 'The annual salary, for python developer Gemma is $34000 + $7000 BONUS!'

# %%
# TASK 3

# %%
[100 + 100 is not 200, 
"c"  in "cats",
100 + 100  is  200, 
5   <=   500 >  100, 
10  is  eval("10"),
40 !=  40, 
10 == 10 and 12 is not  10]
# Out:
# [False, True, True, True, True, False, True]

# %%
# TASK 4

# %%
val1 = 9.5, 5, 10, 4.5 
val2 = 20, 5.5, 3, 50 
val3 = 15, 7, 3, 2.25                                    

shop = {"pizza": val1, "cake": val2, "salad" : val3 }
sorted(shop["pizza"])[0] + sorted(shop["cake"])[0] + sorted(shop["salad"])[0]
# Out:
# 9.75

# %%
# TASK 5

# %%
pals = ["kitten", "puppy", "duck", "owl"]

"""there is a cute {1} and a tiny {0} playing with a {3} next to a {2}""".format(*pals).replace("\n", "").upper().split()[4::4]
# Out:
# ['PUPPY', 'KITTEN', 'OWL', 'DUCK']

# %%
# TASK 6

# %%
pals = ["kitten", "puppy", "duck", "owl"] 

garden = f"""there is a cute {pals[0].upper()} and a tiny {pals[1].upper()}
 playing with a {pals[2].upper()} next to a {pals[3].upper()}""".replace("\n ", " ") 
garden
# Out:
# 'there is a cute KITTEN and a tiny PUPPY playing with a DUCK next to a OWL'

# %%
# TASK 7

# %%
s1 = {4, 50, 10, 2, 70} 
s2 = {1, 300, 10, 2, 70}
s3 = {90, 7, 8, 50, 2, 70}
s1.intersection(s2).intersection(s3)
# Out:
# {2, 70}
