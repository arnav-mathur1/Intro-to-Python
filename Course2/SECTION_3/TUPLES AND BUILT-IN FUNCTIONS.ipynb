# %%
tup1 = 40, 50, 60, 70, 80
tup1
type(tup1)
# Out:
# tuple

# %%
mylist = [10, 20, 30]
tup2 = tuple(mylist)
tup2
type(tup2)
tup3 = tup1 + tup2
tup3
# Out:
# (40, 50, 60, 70, 80, 10, 20, 30)

# %%
tup4 =  "cat", "cat", "cat", "dog", "dog", 10, 10, 10, 10, True
tup4.count(True)
tup3.index(70)
# Out:
# 3

# %%
sum(tup1*2)
max(tup3)
min(tup3)
# Out:
# 10

# %%
tup3
tuple(sorted(tup3))

tup1[0] = "dog"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d99fe365c441> in <module>
#       2 tuple(sorted(tup3))
#       3
# ----> 4 tup1[0] = "dog"
#
# TypeError: 'tuple' object does not support item assignment
