# %%
s1 = {2,2,2,2,2, 10, 20, 30}
s1
# Out:
# {2, 10, 20, 30}

# %%
type(s1)
# Out:
# set

# %%
s2 = [3,3,3,3,3, 10, 40, 20]
s2 = set(s2)
s2
# Out:
# {3, 10, 20, 40}

# %%
s1[0] # sets do not support indexing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-bfed54b371ac> in <module>
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
print(s1)
print(s2)
# Out:
# {2, 10, 20, 30}
# {40, 10, 3, 20}

# %%
s1.union(s2)
# Out:
# {2, 3, 10, 20, 30, 40}

# %%
s1.intersection(s2)
# Out:
# {10, 20}

# %%
s1.difference(s2)
# Out:
# {2, 30}

# %%
s2.difference(s1)
# Out:
# {3, 40}

# %%
s3 = {200, False, "cat"}
s1.update(s3)
s1
# Out:
# {10, 2, 20, 200, 30, False, 'cat'}

# %%
s1.add(400)
s1
# Out:
# {10, 2, 20, 200, 30, 400, False, 'cat'}

# %%
s4 = {400, False, 2}
s1.issuperset(s4)
# Out:
# True

# %%
s4.issubset(s1)
# Out:
# True

# %%
tup = (10, 20, 30, 500, 500, 500, "dog", True, 1, 1, False, 0, 0)
set(tup)
# Out:
# {10, 20, 30, 500, False, True, 'dog'}

# %%
False == 0
True == 1
# Out:
# True
