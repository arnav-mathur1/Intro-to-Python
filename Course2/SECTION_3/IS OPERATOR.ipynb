# %%
a = [1,2,3]
b = [1,2,3]

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
print(id(a))
print(id(b))
# Out:
# 2166594863560
# 2166594863688

# %%
x = y = [10, 20, 30]

# %%
x is y
# Out:
# True

# %%
print(id(x))
print(id(y))
# Out:
# 2166593991816
# 2166593991816

# %%
y[0] = 300
y
# Out:
# [300, 20, 30]

# %%
x is y
x == y
# Out:
# True

# %%
x
# Out:
# [300, 20, 30]

# %%
box1 = ["car", "robot", "ball"] # runs code in 428 nanoseconds

# %%
box2 = ["car"] + ["robot"] + ["ball"] # runs code in 1.71 microseconds

# %%
box1 == box2
# Out:
# True

# %%
box1 is box2
# Out:
# False
