# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and True
True and False
False and False
True or False
# Out:
# True

# %%
10 == 10
10 != 10
10 != 2
50 == 2
# Out:
# False

# %%
200 >= 2001
500 <= 3000
# Out:
# True

# %%
10 > 1 or 4 != 4
# Out:
# True

# %%
var = "house"; var2 = "cinema" ; var3 = "temple"

# %%
"o" in var
"t" in var3
# Out:
# True

# %%
# CHAIN COMPARISON OPERATOR
24 >= 20 > 4 == 4 or 50 < 100 > 40 != 100
# Out:
# True

# %%
"h" in var and "z" not in var3 and 10 > 4 != 50 and 4000 == 5000
# Out:
# False

# %%
print (var, var2, var3)
# Out:
# house cinema temple
