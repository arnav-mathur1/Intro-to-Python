# %%
numbers = [10, 20, 30, 10, 20, 30, 200, 200]

# %%
s1 = {i for i in numbers}
s1
# Out:
# {10, 20, 30, 200}

# %%
set(numbers)
# Out:
# {10, 20, 30, 200}

# %%
words = ["sky", "bar", "star", "python", "slot", "computers"]
x = [len(i) for i in words]
print(x)
# Out:
# [3, 3, 4, 6, 4, 9]

# %%
s2 = {len(i) for i in words}
s2
# Out:
# {3, 4, 6, 9}

# %%
set(x)
# Out:
# {3, 4, 6, 9}
